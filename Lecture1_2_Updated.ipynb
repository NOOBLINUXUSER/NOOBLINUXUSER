# %% [markdown]
# <a href="https://colab.research.google.com/github/NOOBLINUXUSER/NOOBLINUXUSER/blob/main/Lecture1_2_Updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **String in Python**
#
# ---

# %% [markdown]
# **Slice operator ([ ] and [:] ) Beginning index at 0 and Backward index -1.**

# %% [markdown]
# ![string.png](data:image/png;base64,...)

# %%
# a sample string to test
terminator_dialog = "hasta la vista, baby. chill out!!"

# print the full string
print(terminator_dialog)

# get and print the 'hasta la'
#=======================================
sub_str = terminator_dialog[0:8]
print(sub_str)

#sub_str = terminator_dialog[:8] --> Same as [0:8]
sub_str = terminator_dialog[-33:-25]
print(sub_str)

# print the sub string 'baby.' from the dialogue
#---------------------------------------------------------


# print the sub string 'chill out!!' in 3 different ways.

# follow the above example to solve this problem.
#---------------------------------------------------------
# Out:
# hasta la vista, baby. chill out!!
# hasta la
# hasta la

# %% [markdown]
# **Exercise 1:**
#
#
# 1.   Take the following string as input from the user: **I am the best in Python!! and I mean it. I will achieve A in this course for sure.**
# 2.   Print the string.
# 3.   Print the sub-string 'I am the best' using forward indexing
# 4.   Pringt the sub-string 'achieve A' using backward indexing
